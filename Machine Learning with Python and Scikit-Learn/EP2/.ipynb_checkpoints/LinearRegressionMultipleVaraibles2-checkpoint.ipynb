# %%
# TOPIC GOING COVERED TODAY
# 1.Data Preprocessing: Handling NA values
# 2.LINEAR REGRESSION USING MULTIPLE VALUES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('homeprices.csv')
print(df)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.loc[2, 'bedrooms'] = np.nan
print(df)
df['bedrooms'] = df['bedrooms'].fillna(df['bedrooms'].median())
print(df)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area' ,'bedrooms', 'age']], df['price'])
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  112.06244194 23388.88007794 -3231.71790863]
# 221323.0018654043

# %%
print(reg.predict([[3000, 3, 40]]))
# Out:
# [498408.25158031]
# C:\Users\Murugan Thanganadar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(reg.predict([[2500, 4, 5]]))
# Out:
# [578876.03748933]
# C:\Users\Murugan Thanganadar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
################## EXERCISE #######################################

# %%
df2 = pd.read_csv('hiring.csv')
print(df2)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df2temp = df2.copy()
print(df2temp)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
#preprocesing
df2temp['experience'] = df2temp['experience'].fillna('zero')
print(df2temp)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df2temp.rename(columns = {
    'test_score(out of 10)' : 'test_score',
    'interview_score(out of 10)' : 'interview_score'
}, inplace = True)
print(df2temp)
# Out:
#   experience  test_score  interview_score  salary($)
# 0       zero         8.0                9      50000
# 1       zero         8.0                6      45000
# 2       five         6.0                7      60000
# 3        two        10.0               10      65000
# 4      seven         9.0                6      70000
# 5      three         7.0               10      62000
# 6        ten         NaN                7      72000
# 7     eleven         7.0                8      80000

# %%
df2temp['test_score'] = df2temp['test_score'].fillna(df2temp['test_score'].median())
print(df2temp)
# Out:
#   experience  test_score  interview_score  salary($)
# 0       zero         8.0                9      50000
# 1       zero         8.0                6      45000
# 2       five         6.0                7      60000
# 3        two        10.0               10      65000
# 4      seven         9.0                6      70000
# 5      three         7.0               10      62000
# 6        ten         8.0                7      72000
# 7     eleven         7.0                8      80000

# %%
from word2number import w2n
# testing
print(w2n.word_to_num('two point three'))
# Out:
# 2.3

# %%
def changeWordToNumber(x):
    return w2n.word_to_num(x)

df2temp['experience'] = df2temp['experience'].apply(changeWordToNumber)

print(df2temp)
# Out:
#    experience  test_score  interview_score  salary($)
# 0           0         8.0                9      50000
# 1           0         8.0                6      45000
# 2           5         6.0                7      60000
# 3           2        10.0               10      65000
# 4           7         9.0                6      70000
# 5           3         7.0               10      62000
# 6          10         8.0                7      72000
# 7          11         7.0                8      80000

# %%
# Training the machine learning model
reg = linear_model.LinearRegression()
reg.fit(df2temp[['experience', 'test_score', 'interview_score']], df2temp['salary($)'])
# Out:
# LinearRegression()

# %%
print(reg.predict([[2, 9, 6]]))
# Out:
# [53205.96797671]
# C:\Users\Murugan Thanganadar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(reg.predict([[12, 10, 10]]))
# Out:
# [92002.18340611]
# C:\Users\Murugan Thanganadar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
